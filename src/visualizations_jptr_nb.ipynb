# %%
# %matplotlib inline

# 1. get data
# !python get_data.py

# 2. clean data
# !python clean_data.py

# 3. run analysis
# !python run_analysis.py

# 4. generate visualizations
# %run visualize_results.py
# Out:
# Extracted raw CSV: ../data/raw/bts_2023_Q1.csv
# Extracted raw CSV: ../data/raw/bts_2023_Q2.csv
# Extracted raw CSV: ../data/raw/bts_2023_Q3.csv
# Extracted raw CSV: ../data/raw/bts_2023_Q4.csv
# Extracted raw CSV: ../data/raw/bts_2024_Q1.csv
# Extracted raw CSV: ../data/raw/bts_2024_Q2.csv
# Extracted raw CSV: ../data/raw/bts_2024_Q3.csv
# Extracted raw CSV: ../data/raw/bts_2024_Q4.csv
# Extracted raw CSV: ../data/raw/bts_2025_Q1.csv
# Extracted raw CSV: ../data/raw/bts_2025_Q2.csv
# Combined shape: (17208845, 7)
# Top 10 routes:
#   ORIGIN DEST  count
# 0    LAX  JFK  83542
# 1    JFK  LAX  83185
# 2    LAX  EWR  72805
# 3    EWR  LAX  71944
# 4    LAX  BOS  68537
# 5    SFO  JFK  67607
# 6    JFK  SFO  67586
# 7    BOS  LAX  67518
# 8    SFO  EWR  65466
# 9    EWR  SFO  65399
# --------- Quarterly Average Fare by Route ---------
#       route  YEAR  QUARTER    avg_fare
# 0   BOS-LAX  2023        1  387.095797
# 1   BOS-LAX  2023        2  440.797055
# ...
